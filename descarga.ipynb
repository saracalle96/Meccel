# %%
from urllib.request import urlretrieve
#notebook para descargar los notebook del profesor

# %%
urlretrieve("https://raw.githubusercontent.com/seap-udea/meccel-clase-profesor/refs/heads/main/CuadernoCeleste-VirialRelajacion.ipynb", "virial.ipynb")
# Out:
# ('virial.ipynb', <http.client.HTTPMessage at 0x70339578bf80>)
